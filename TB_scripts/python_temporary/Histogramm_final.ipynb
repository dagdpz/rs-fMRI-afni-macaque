# %%
#predrug
import matplotlib.pyplot as plt
import numpy as np

#CL-CL; predrug
CL_CL = []
with open ('predrug_sub-Linus_epi_CHARM_in_NMT_v2.1_sym_05mm_001.txt', 'rt') as myfile: 
     for i, line in enumerate(myfile, start=1):  
        if i <= 6:  
            continue
        if i > 23:  
            break
        line = line.strip()             
        if not line:
            continue
        parts = line.split()
        CL_CL.append((float(parts[0]), float(parts[1]), float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5]), 
                      float(parts[6]), float(parts[7]), float(parts[8]), float(parts[9]), float(parts[10]), 
                      float(parts[11]), float(parts[12]), float(parts[13]), float(parts[14]), float(parts[15]), float(parts[16])))
print("CL_CL:", CL_CL)

#CR-CR; predrug
CR_CR = []
with open ('predrug_sub-Linus_epi_CHARM_in_NMT_v2.1_sym_05mm_001.txt', 'rt') as myfile:  
     for i, line in enumerate(myfile, start=1):  
        if i <= 23:  
            continue
        if i > 40:  
            break
        line = line.strip()               
        if not line:
            continue
        parts = line.split()
        CR_CR.append((float(parts[17]), float(parts[18]), float(parts[19]), float(parts[20]), float(parts[21]), float(parts[22]), 
                      float(parts[23]), float(parts[24]), float(parts[25]), float(parts[26]), float(parts[27]), 
                      float(parts[28]), float(parts[29]), float(parts[30]), float(parts[31]), float(parts[32]), float(parts[22])))
print("CR_CR:", CR_CR)

#CR-CL; predrug
CR_CL = []
with open ('predrug_sub-Linus_epi_CHARM_in_NMT_v2.1_sym_05mm_001.txt', 'rt') as myfile:  
     for i, line in enumerate(myfile, start=1):  
        if i <= 23:  
            continue
        if i > 40:  
            break
        line = line.strip()               
        if not line:
            continue
        parts = line.split()
        CR_CL.append((float(parts[0]), float(parts[1]), float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5]), 
                      float(parts[6]), float(parts[7]), float(parts[8]), float(parts[9]), float(parts[10]), 
                      float(parts[11]), float(parts[12]), float(parts[13]), float(parts[14]), float(parts[15]), float(parts[16])))
print("CR_CL:", CR_CL)


# Extract all values from the tuples into flat lists
CL_CL_values = [value for tup in CL_CL for value in tup]
CR_CR_values = [value for tup in CR_CR for value in tup]
CR_CL_values = [value for tup in CR_CL for value in tup]

# removing duplicates
unique_values_CL = np.unique(CL_CL_values)
unique_values_CR = np.unique(CR_CR_values)
unique_values_CRCL = np.unique(CR_CL_values)

# excluding values == 1
filtered_values_CL = unique_values_CL[unique_values_CL != 1.0]
filtered_values_CR = unique_values_CR[unique_values_CR != 1.0]
filtered_values_CRCL = unique_values_CRCL[unique_values_CRCL != 1.0]

# create diagram for CL_CL
plt.figure()
plt.hist(filtered_values_CL, bins='auto', alpha=0.7, label='CL_CL', color='blue')
plt.title('Histogramm from CL_CL')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()

# create diagram for CR_CR
plt.figure()
plt.hist(filtered_values_CR, bins='auto', alpha=0.7, label='CR_CR', color='red')
plt.title('Histogramm from CR_CR')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()

# Show both diagramms
plt.show()

# create histogram for both data
plt.hist(filtered_values_CL, bins=6, alpha=0.7, label='CL_CL', color='blue')
plt.hist(filtered_values_CR, bins=6, alpha=0.7, label='CR_CR', color='red')


plt.title('Comparison of CL_CL vs CR_CR')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()      

# create diagramm for CR_CL
plt.figure()
plt.hist(filtered_values_CRCL, bins='auto', alpha=0.7, label='CR_CL', color='blue')
plt.title('Histogramm from CR_CL')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
#plt.grid(True)
plt.legend()
plt.show()

#postdrug
import matplotlib.pyplot as plt
import numpy as np

#CL-CL
CL_CL_postdrug = []
with open ('postdrug_sub-Linus_epi_CHARM_in_NMT_v2.1_sym_05mm_001.txt', 'rt') as myfile:  
     for i, line in enumerate(myfile, start=1):  
        if i <= 6:  
            continue
        if i > 23: 
            break
        line = line.strip()              
        if not line:
            continue
        parts = line.split()
        CL_CL_postdrug.append((float(parts[0]), float(parts[1]), float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5]), 
                      float(parts[6]), float(parts[7]), float(parts[8]), float(parts[9]), float(parts[10]), 
                      float(parts[11]), float(parts[12]), float(parts[13]), float(parts[14]), float(parts[15]), float(parts[16])))
print("CL_CL_postdrug:", CL_CL_postdrug)

#CR-CR
CR_CR_postdrug = []
with open ('postdrug_sub-Linus_epi_CHARM_in_NMT_v2.1_sym_05mm_001.txt', 'rt') as myfile:  
     for i, line in enumerate(myfile, start=1):  
        if i <= 23:  
            continue
        if i > 40:  
            break
        line = line.strip()               
        if not line:
            continue
        parts = line.split()
        CR_CR_postdrug.append((float(parts[17]), float(parts[18]), float(parts[19]), float(parts[20]), float(parts[21]), float(parts[22]), 
                      float(parts[23]), float(parts[24]), float(parts[25]), float(parts[26]), float(parts[27]), 
                      float(parts[28]), float(parts[29]), float(parts[30]), float(parts[31]), float(parts[32]), float(parts[22])))
print("CR_CR_postdrug:", CR_CR_postdrug)

#CR-CL
CR_CL_postdrug = []
with open ('postdrug_sub-Linus_epi_CHARM_in_NMT_v2.1_sym_05mm_001.txt', 'rt') as myfile:  
     for i, line in enumerate(myfile, start=1):  
        if i <= 23:  
            continue
        if i > 40:  
            break
        line = line.strip()               
        if not line:
            continue
        parts = line.split()
        CR_CL_postdrug.append((float(parts[0]), float(parts[1]), float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5]), 
                      float(parts[6]), float(parts[7]), float(parts[8]), float(parts[9]), float(parts[10]), 
                      float(parts[11]), float(parts[12]), float(parts[13]), float(parts[14]), float(parts[15]), float(parts[16])))
print("CR_CL:", CR_CL_postdrug)

# Extract all values from the tuples into flat lists
CL_CL_values_postdrug = [value for tup in CL_CL_postdrug for value in tup]
CR_CR_values_postdrug = [value for tup in CR_CR_postdrug for value in tup]
CR_CL_values_postdrug = [value for tup in CR_CL_postdrug for value in tup]

# removing of duplicates
unique_values_CL_postdrug = np.unique(CL_CL_values_postdrug)
unique_values_CR_postdrug = np.unique(CR_CR_values_postdrug)
unique_values_CRCL_postdrug = np.unique(CR_CL_values_postdrug)

# exclude values == 1
filtered_values_CL_postdrug = unique_values_CL_postdrug[unique_values_CL_postdrug != 1.0]
filtered_values_CR_postdrug = unique_values_CR_postdrug[unique_values_CR_postdrug != 1.0]
filtered_values_CRCL_postdrug = unique_values_CRCL_postdrug[unique_values_CRCL_postdrug != 1.0]

# create diagramm for CL_CL
plt.figure()
plt.hist(filtered_values_CL_postdrug, bins='auto', alpha=0.7, label='CL_CL_postdrug', color='blue')
plt.title('Histogramm from CL_CL; postdrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()

# create diagramm for CR_CR
plt.figure()
plt.hist(filtered_values_CR_postdrug, bins='auto', alpha=0.7, label='CR_CR_postdrug', color='red')
plt.title('Histogramm from CR_CR; postdrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()

# Show both diagramms
plt.show()

# create diagramm for both data
plt.hist(filtered_values_CL_postdrug, bins=6, alpha=0.7, label='CL_CL_postdrug', color='blue')
plt.hist(filtered_values_CR_postdrug, bins=6, alpha=0.7, label='CR_CR_postdrug', color='red')

plt.title('Comparison of CL_CL vs CR_CR; postdrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()      

# create diagramm for CR_CL
plt.figure()
plt.hist(filtered_values_CRCL_postdrug, bins='auto', alpha=0.7, label='CR_CL_postdrug', color='blue')
plt.title('Histogramm from CR_CL_postdrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()


#post and presdrug
# create diagramm for CR_CL
plt.figure()
plt.hist(filtered_values_CRCL_postdrug, bins='auto', alpha=0.7, label='CR_CL_postdrug', color='blue')
plt.hist(filtered_values_CRCL, bins='auto', alpha=0.7, label='CR_CL', color='red')
plt.title('Histogramm from CR_CL both post and predrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# create diagramm for CL-CL
plt.figure()
plt.hist(filtered_values_CL_postdrug, bins='auto', alpha=0.7, label='CL_postdrug', color='blue')
plt.hist(filtered_values_CL, bins='auto', alpha=0.7, label='CL_predrug', color='red')
plt.title('Histogramm from CL_CL both post and predrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# create diagramm for CR_CL
plt.figure()
plt.hist(filtered_values_CR_postdrug, bins='auto', alpha=0.7, label='CR_postdrug', color='blue')
plt.hist(filtered_values_CR, bins='auto', alpha=0.7, label='CR_predrug', color='red')
plt.title('Histogramm from CR_CR both post and predrug')
plt.xlabel('Correlation coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# CL_CL: [(1.0, 0.1163, 0.0516, 0.023, -0.0211, 0.0202, 0.0241, 0.0271, -0.0357, -0.0648, 0.0247, 0.0462, -0.0266, 0.0301, 0.0488, 0.0075, 0.0012), (0.1163, 1.0, 0.2164, 0.0891, 0.1538, 0.0766, 0.1035, 0.1024, 0.0578, 0.1235, 0.1378, 0.3465, 0.2517, 0.1207, 0.0438, 0.2311, 0.1604), (0.0516, 0.2164, 1.0, 0.2928, 0.1122, 0.1587, 0.1778, 0.2135, 0.0695, 0.0705, 0.2411, 0.3427, 0.1101, 0.0251, 0.0915, 0.3306, 0.1875), (0.023, 0.0891, 0.2928, 1.0, 0.4717, 0.3033, 0.3608, 0.1587, 0.0802, -0.022, 0.1391, 0.1725, 0.0887, 0.1174, 0.0654, 0.2878, 0.1933), (-0.0211, 0.1538, 0.1122, 0.4717, 1.0, 0.184, 0.2353, 0.0, 0.0599, -0.0179, 0.0204, 0.0867, 0.3028, 0.3183, 0.0071, 0.1443, 0.1177), (0.0202, 0.0766, 0.1587, 0.3033, 0.184, 1.0, 0.3986, 0.3369, 0.0176, -0.0172, 0.1235, 0.1548, 0.0637, 0.0147, 0.0479, 0.3012, 0.1461), (0.0241, 0.1035, 0.1778, 0.3608, 0.2353, 0.3986, 1.0, 0.1624, 0.0246, -0.0183, 0.1785, 0.2422, 0.137, 0.0498, 0.2114, 0.3523, 0.1769), (0.0271, 0.1024, 0.2135, 0.1587, 0.0, 0.3369,
# ...
